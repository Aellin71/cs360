# %% [markdown]
# <a href="https://colab.research.google.com/github/Aellin71/cs360/blob/main/LEX_and_YACC_CompilerLab10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LEX and YACC Compiler in Colab
#
# Drawbacks:
# * Regular interrupts (Ctrl+D, Ctrl+C) for shell won't work in Colab while inputting for program.
# <br>Workaround: Store your inputs in a txt file and pass it to the program.

# %%
#@title Install *prerqeuisites* (run this cell first to work on LEX/YACC)
# !sudo apt install flex bison
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# bison is already the newest version (2:3.8.2+dfsg-1build1).
# flex is already the newest version (2.6.4-8build2).
# 0 upgraded, 0 newly installed, 0 to remove and 5 not upgraded.

# %%
#@title Lex program to count identifiers
# %%writefile program.l

# %{
    int count=0;
%}
%%
    /* match identifier */
    /* ENTER REGULAR EXPRESSION BELOW - hint: check notes for RegExp */
^[a-zA-Z_][a-zA-Z0-9_]* count++;
%%

int yywrap(void) {
    return 1;
}

int main(int argc, char *argv[]) {
    if(argc!=2){
        printf("Usage:\n\t./a.out <FILENAME>\n");
        exit(0);
    }
    yyin=fopen(argv[1],"r");

    yylex();
    printf("number of identifiers = %d\n", count);

    fclose(yyin);
    return 0;
}
# Out:
# Overwriting program.l

# %%
#@title Create a file with one possible identifier per line to check
# %%writefile program.txt
123
num
num2
2num
123xyz
_123
_num
num_123
123_num
# Out:
# Overwriting program.txt

# %%
#@title Shell Execution (you can rewrite the commands as per your need, eg. if you want to include a file as an input)
# %%shell

lex -l program.l
gcc lex.yy.c
./a.out program.txt
# Out:
# 123
#
#
# 2num
# 123xyz
#
#
#
# 123_num
# number of identifiers = 5

# %%
#@title Writing Lex program to find email addresses
# %%writefile program.l

# %{
%}

%%
[a-zA-Z.0-9]+@[a-zA-Z]+\.[a-zA-Z]+(\.[a-zA-Z0-9]+)* printf("email: %s\n", yytext);
.|\n
%%

int main(int argc, char **argv) {
    if(argc!=2){
        printf("Usage:\n\t./a.out <FILENAME>\n");
        exit(0);
    }
    yyin=fopen(argv[1],"r");
    yylex();
    return 0;
}

int yywrap() {
    return 1;
}
# Out:
# Overwriting program.l

# %%
#@title Create a file with several possible email addresses
# %%writefile program.txt
no way kruse@juniata.edu
helpe@nune LCKruse@yahoo.com
four gwk@cfm.brown.edu
kruseb@msn.com five
six
seven
Jerry.Kruse@juniata.edu and more
nine Jerry-Kruse@juniata.edu
ten
help@juniata.edu and hr@ibm.co.de
jerry@.com @yahoo.com first@lame
# Out:
# Overwriting program.txt

# %%
#@title Shell Execution (you can rewrite the commands as per your need, eg. if you want to include a file as an input)
# %%shell

lex -l program.l
gcc lex.yy.c
./a.out program.txt
# Out:
# email: kruse@juniata.edu
# email: LCKruse@yahoo.com
# email: gwk@cfm.brown.edu
# email: kruseb@msn.com
# email: Jerry.Kruse@juniata.edu
# email: Kruse@juniata.edu
# email: help@juniata.edu
# email: hr@ibm.co.de
